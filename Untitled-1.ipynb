# %%
import pandas as pd

# %%
brecha = pd.read_excel("C:/Users/lravlic/Downloads/Materiales Brecha Costo Premium.xlsx")

# %%
brecha
# Out:
#           Material  Sector       Marca       Tipo
# 0   BMW MotorradAC      74    Motorrad    OEM BMW
# 1         JaguarAC      65      JAGUAR  OEM DITEC
# 2         JaguarBC      65      JAGUAR  OEM DITEC
# 3     Land RoverAC      66  Land rover  OEM DITEC
# 4     Land RoverBC      66  Land rover  OEM DITEC
# 5        PorscheAC      68     Porsche  OEM DITEC
# 6        PorscheBC      68     Porsche  OEM DITEC
# 7          VolvoAC      67       Volvo  OEM DITEC
# 8          VolvoBC      67       Volvo  OEM DITEC
# 9         JaguarCC      65      JAGUAR  OEM DITEC
# 10    Land RoverCC      66  Land rover  OEM DITEC
# 11       PorscheCC      68     Porsche  OEM DITEC
# 12         VolvoCC      67       Volvo  OEM DITEC
# 13           BMWAC      72         BMW    OEM BMW
# 14           BMWBC      72         BMW    OEM BMW
# 15           BMWCC      72         BMW    OEM BMW
# 16  BMW MotorradBC      74    Motorrad    OEM BMW
# 17  BMW MotorradCC      74    Motorrad    OEM BMW
# ...

# %%
mara= pd.read_csv('Mara_consolidada.csv')

# %%
brecha = brecha[["Material", "Marca","Tipo"]]
mara = mara[["Material", "Marca","Tipo"]]

# %%
mara_final = pd.concat([mara,brecha])

# %%
mara_final.to_csv("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Gerenciamiento MOS/Panel PBI/automatizacion/Mara_consolidada.csv")

# %%
brecha
# Out:
#           Material       Marca       Tipo
# 0   BMW MotorradAC    Motorrad    OEM BMW
# 1         JaguarAC      JAGUAR  OEM DITEC
# 2         JaguarBC      JAGUAR  OEM DITEC
# 3     Land RoverAC  Land rover  OEM DITEC
# 4     Land RoverBC  Land rover  OEM DITEC
# 5        PorscheAC     Porsche  OEM DITEC
# 6        PorscheBC     Porsche  OEM DITEC
# 7          VolvoAC       Volvo  OEM DITEC
# 8          VolvoBC       Volvo  OEM DITEC
# 9         JaguarCC      JAGUAR  OEM DITEC
# 10    Land RoverCC  Land rover  OEM DITEC
# 11       PorscheCC     Porsche  OEM DITEC
# 12         VolvoCC       Volvo  OEM DITEC
# 13           BMWAC         BMW    OEM BMW
# 14           BMWBC         BMW    OEM BMW
# 15           BMWCC         BMW    OEM BMW
# 16  BMW MotorradBC    Motorrad    OEM BMW
# 17  BMW MotorradCC    Motorrad    OEM BMW
# 18          MiniAC        Mini    OEM BMW
# 19          MiniBC        Mini    OEM BMW
# 20          MiniCC        Mini    OEM BMW
